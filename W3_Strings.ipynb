# %% [markdown]
# <a href="https://colab.research.google.com/github/sampathwijayasinghe/My_Learning_Collectrion/blob/main/W3_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text1="     I love to travel "
text2="      around the world with my family"
print(text1.strip() + text2.strip())
# Out:
# I love to travelaround the world with my family

# %%
age = 36
#This will produce an error:
txt = "My name is John, I am "
print(txt + str(age))
# Out:
# My name is John, I am 36

# %%
releasedon=2012
boyka= f"Undisputed is a very good movie released on {releasedon}"
print(boyka)
# Out:
# Undisputed is a very good movie released on 2012

# %%
tt= 203
ll=f"this is a test{ tt:.2f} message"
print(ll)
# Out:
# this is a test203.00 message

# %%
txt = "We are the so-called \"Vikings\" from the north."
print(txt)
# Out:
# We are the so-called "Vikings" from the north.

# %%
txt = "We are the so-called \'wikings\' from the north."
print(txt)
# Out:
# We are the so-called 'wikings' from the north.
