# %% [markdown]
# <a href="https://colab.research.google.com/github/sampathwijayasinghe/My_Learning_Collectrion/blob/main/W3School_up_to_format_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello 2026")
print("Hello 2026")
print("Hello 2026")
# Out:
# Hello 2026
# Hello 2026
# Hello 2026

# %%
if 5 > 3:
  print("Five is greater than three")
# Out:
# Five is greater than three

# %%
x=("hello")
y=("sam")
print(x+y)
# Out:
# hellosam

# %%
print(5+2)
# this is a line comment
// I dont know
what this is //
# Out:
#   File "/tmp/ipython-input-3789273637.py", line 3
#     // I dont know
#     ^
# SyntaxError: invalid syntax

# %%
print("first"); print("second"); print("bye!"); print('new')
# Out:
# first
# second
# bye!
# new

# %%
print('hello one', end="")
print(' next')
# Out:
# hello one next

# %%
print(3)
print(4)
print(5)
print(7);print(8);print(9)
print ("0")
print(9*5)
print(0/9)
print("Reels", 100, "Films")
# Out:
# 3
# 4
# 5
# 7
# 8
# 9
# 0
# 45
# 0.0
# Reels 100 Films

# %%
x=6   #this is integer
x="King" #this is a string

print(x);
# Out:
# King

# %%
a=10
b=10.3
c="hgh"
print(type (c))
print(type(a))
# Out:
# <class 'str'>
# <class 'int'>

# %%
a=5
A=6
print(A)
# Out:
# 6

# %%
myvar="fog"
_my_var="grup"
_myvar='hot'
print(_myvar)
# Out:
# hot

# %%
x,y,z="Orange","Banana","Mango"
print(x);print(y);print(z)
# Out:
# Orange
# Banana
# Mango

# %%
x=y=z="Kivi"
print(y)
print(x)
print(z)
# Out:
# Kivi
# Kivi
# Kivi

# %%
fruits=["hi","hello","halo"]
x=y=z=fruits
print(x)
print(y)
print(z)
# Out:
# ['hi', 'hello', 'halo']
# ['hi', 'hello', 'halo']
# ['hi', 'hello', 'halo']

# %%
j="i "
k="don't"
l="know"
print(j+k+l)
# Out:
# i don'tknow

# %%
a="New year starts today"

def myfunc():
  print("Today is Jan 1" + a)

myfunc()
# Out:
# Today is Jan 1New year starts today

# %%
c="i see the sea, "

def myfunc():
  global d
  d="I love the beach resort"
  print(c+d)
myfunc()

def myfunc2():
  print(c+d)
myfunc2()
# Out:
# i see the sea, I love the beach resort
# i see the sea, I love the beach resort

# %%
x = 1.10
y = 1.0
z = -35.59

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x = 3+5j
y = 5j
z = -5j

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
import random
print(random.randrange(1,10))
# Out:
# 2

# %%
x=1
y=36.6
z=3698745

print(x+int(y)+int(z))
# Out:
# 3698782

# %%
a=""" lorem ipsum, little brown bear jump into
the white paint bucket"""

print(a)
# Out:
#  lorem ipsum, little brown bear jump into
# the white paint bucket

# %%
a="plane"
print(a[0])
# Out:
# p

# %%
for x in "banana":
  print (x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
x="Mango"
print(len(a))
# Out:
# 5

# %%
z="I should have stay at home"
print("should" in z)
# Out:
# True

# %%
g="I think I am addicted to watch youtube"
if "I" in g:
  print("Yes,I in g")
# Out:
# Yes,I in g

# %%
x="It was a heavy rain fall happened in last November"
if "rain" not in x:
  print("yes, the word 'rain' is in x")
  """ print ("No, the word 'sunny' is not in x") """

# %%
x="It was a heavy rain fall happened in last November"
if "rain" not in x:
  print("yes, the word 'rain' is in x")

# %%
tt="Hello World"
print(tt[2:])
# Out:
# llo World

# %%
b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl

# %%
f="sampath"
print(f.upper())
# Out:
# SAMPATH

# %%
j="HOSPITAL"
print(j.lower())
# Out:
# hospital

# %%
h="    ghghcc bnjy kkhl llop"
print(h.replace("g","w"))
# Out:
#     whwhcc bnjy kkhl llop

# %%
txt="Cosmo, co, orange"
print(txt.split(","))
# Out:
# ['Cosmo', ' co', ' orange']
