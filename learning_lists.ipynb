# %% [markdown]
# <a href="https://colab.research.google.com/github/sampathwijayasinghe/My_Learning_Collectrion/blob/main/learning_lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers =[2,4,6,8,10]
count = len(numbers)

if count <3:
 print (f"list has {count} elements")

else:
  print("list")
# Out:
# list

# %% [markdown]
# Create & Print
#
# Create a list of 5 numbers and print:
#
# the full list
#
# the first element
#
# the last element

# %%
mylist=[10,11,21,23,25]
print(mylist)
print(mylist[0])
print(mylist[4])
# Out:
# [10, 11, 21, 23, 25]
# 10
# 25

# %% [markdown]
# Change Value
#
# fruits = ["apple", "banana", "cherry"]
#
# Change "banana" to "orange" and print the list.

# %%
fruits = ["apple", "banana", "cherry"]
fruits(1, "orrange"):
print(fruits())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1480884456.py in <cell line: 0>()
#       1 fruits = ["apple", "banana", "cherry"]
# ----> 2 fruits(1, "orrange")
#       3 print(fruits())
#
# TypeError: 'list' object is not callable
